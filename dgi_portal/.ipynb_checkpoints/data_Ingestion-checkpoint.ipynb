# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
url_data= "C:\\Users\\HAJJARI\\Desktop\\AI\\13-GithubRepos\\DGI-Bourse-Portal\\Bourse_Casablanca\\Bourse_Casablanca\\notebooks\\Bourse_Cleaned.json"
df=pd.read_json(url_data, orient='records')

# %%
print(df.shape)
df.head()
# Out:
# (76, 11)
#         side_full_name                                         management  \
# 0            ALLIANCES  {"Chairman and CEO": "LAZRAQ Alami", "Chairman...
# 1         AFRIQUIA GAZ  {"Chairman of the Bord of Directors": "WAKRIM ...
# 2                 AFMA  {"Chairman and CEO": "BENSAID Farid", "Deputy ...
# 3              AKDITAL  {"Chairman and CEO": "TALIB M. Rochdi", "Deput...
# 4  ALUMINIUM DU  MAROC  {"Chairman of the Bord of Directors": "EL ALAM...
#
#                             shareholders_pourcentage  \
# 0  {"NAFAKH LAZRAQ ALAMI MOHAMED": "51,68", "DIVE...
# 1  {"Afriquia SMDC": "38,00", "AKWA HOLDING": "30...
# 2  {"TENOR FINANCES": "39,48", "DIVERS ACTIONNAIR...
# 3  {"DIVERS ACTIONNAIRES ": "31,58", "TALIB Rochd...
# 4  {"HOLDING S.A": "32,67", "DIVERS ACTIONNAIRES ...
#
#                                       Info_key_value  \
# 0  {"Company name ": "ALLIANCES DEVELOPPEMENT IMM...
# 1  {"Company name ": "AFRIQUIA GAZ", "Corporate a...
# ...

# %%
for column in list(df.columns):
    print(column + " : ",df.loc[0,column])
    print('\n')
# Out:
# side_full_name :  ALLIANCES
#
#
# management :  {"Chairman and CEO": "LAZRAQ Alami", "Chairman Advisor": "AMMOR Ahmed", "Deputy Managing director": "NAFAKH LAZRAQ Mohamed", "Deputy Managing Director Social and Middle Class Real Estate Development": "KABBAJ Youssef"}
#
#
# shareholders_pourcentage :  {"NAFAKH LAZRAQ ALAMI MOHAMED": "51,68", "DIVERS ACTIONNAIRES ": "23,30", "RCAR": "8,39", "HOLPAR": "4,37", "CAISSE MAROCAINE DE RETRAITE (CMR)": "4,13", "Société Financière Internationale": "2,95", "EL BELGHAMI FARIDA": "1,82", "SCR (Société Centrale de Réassurance)": "1,54", "UPLINE": "0,72", "NAFAKH LAZRAQ OTHMAN": "0,36", "NAFAKH LAZRAQ MOUNA": "0,36", "NAFAKH LAZRAQ OMAR": "0,36", "NAFAKH LAZRAQ MUSTAPHA": "0,02", "Total": "100,00"}
#
#
# ...

# %% [markdown]
# ### Spliting the data into tables

# %%
# Create an empty DataFrame to store the result
Company = pd.DataFrame()

# Iterate through rows of the original DataFrame
for index, row in df.iterrows():
    # Convert the value column to a dictionary (assuming it's a valid JSON-like format)
    values_dict = eval(row['Info_key_value'])
    
    # Create a temporary DataFrame from the dictionary
    temp_df = pd.DataFrame.from_dict(values_dict, orient='index').T
    
    # Append the temporary DataFrame to the result DataFrame
    Company = Company.append(temp_df, ignore_index=True)

# Reset the index of the new DataFrame
Company.reset_index(drop=True, inplace=True)

# Rename columns if needed
Company.rename(columns=lambda x: x.strip(), inplace=True)

# Append the instrument_link, Publications_page columns
Company["Publications_page"]= df["Publications_page"]
Company["instrument_link"]= df["instrument_link"]

# order columns
wanted_order=["Company name","Corporate address","External auditors","Length of fiscal year","Date of creation","Date of IPO","Social object","Publications_page","instrument_link"]
Company=Company[wanted_order]
Company["Company name"]=df["side_full_name"]
Company.rename(columns={'Company name': 'name', 'Corporate address': 'address','External auditors':'external_auditor','Length of fiscal year':'fiscal_year_length','Date of creation':'creation_date','Date of IPO':'ipo_date','Social object':'social_object','Publications_page':'publications_page'}, inplace=True)
Company.creation_date=pd.to_datetime(Company.creation_date)
Company.ipo_date=pd.to_datetime(Company.ipo_date)
# Display the new DataFrame
Company.head()
# Out:
#                   name                                            address  \
# 0            ALLIANCES                                                  -
# 1         AFRIQUIA GAZ  139. boulevard Moulay Ismaïl  - Roche Noires -...
# 2                 AFMA                        22 Boulevard Moulay Youssef
# 3              AKDITAL                   246 route de l’Oasis, Casablanca
# 4  ALUMINIUM DU  MAROC                                                  -
#
#                           external_auditor fiscal_year_length creation_date  \
# 0                           DELOITTE AUDIT                 12    1994-06-13
# 1  Abdellah RHALLAM / Abdelaziz AL MECHATT                 12    1992-01-01
# 2               KPMG / Afric Audit Conseil                 12    1953-01-01
# 3                         Mazars, Omnipact                 12    2016-08-19
# 4         A&T Auditeurs Consultants et BDO                 12    1976-01-01
#
# ...

# %%
engine= create_engine("postgresql://root:root@localhost:5432/bourse")

# %%
engine.connect()

# %%
Company.to_sql(name='api_company',index=False,con=engine,if_exists='append')

# %%
key_list = []
value_list = []
sides=[]


management_list = df['management'].tolist()
side_full_name_list = df['side_full_name'].tolist()

for management_dict, side_full_name in zip(management_list, side_full_name_list):
    for key, value in eval(management_dict).items():
        key_list.append(key)
        value_list.append(value)
    mult_sides= [side_full_name]*len(eval(management_dict))
    sides.extend(mult_sides)         
Management = pd.DataFrame({
    'post': key_list,
    'name': value_list,
    'company_id': sides
})
wanted_order=['name','post','company_id']
Management=Management[wanted_order]

# %%
Management.head()
# Out:
#                     name                                               post  \
# 0           LAZRAQ Alami                                   Chairman and CEO
# 1            AMMOR Ahmed                                   Chairman Advisor
# 2  NAFAKH LAZRAQ Mohamed                           Deputy Managing director
# 3         KABBAJ Youssef  Deputy Managing Director Social and Middle Cla...
# 4             WAKRIM Ali                  Chairman of the Bord of Directors
#
#      company_id
# 0     ALLIANCES
# 1     ALLIANCES
# 2     ALLIANCES
# 3     ALLIANCES
# 4  AFRIQUIA GAZ

# %%
Management.to_sql(name='api_management',index=False,con=engine,if_exists='append')

# %%
key_list = []
value_list = []
sides=[]


shareholders_list = df['shareholders_pourcentage'].tolist()
side_full_name_list = df['side_full_name'].tolist()

for shareholder_dict, side_full_name in zip(shareholders_list, side_full_name_list):
    for key, value in eval(shareholder_dict).items():
        if key!='Total':
            key_list.append(key)
            value_list.append(value)
    mult_sides= [side_full_name]*(len(eval(shareholder_dict))-1)
    sides.extend(mult_sides)  
shareholders = pd.DataFrame({
    'holder': key_list,
    'percentage': value_list,
    'company_id': sides
})

# %%
shareholders.head()
# Out:
#                                holder percentage company_id
# 0         NAFAKH LAZRAQ ALAMI MOHAMED      51,68  ALLIANCES
# 1                DIVERS ACTIONNAIRES       23,30  ALLIANCES
# 2                                RCAR       8,39  ALLIANCES
# 3                              HOLPAR       4,37  ALLIANCES
# 4  CAISSE MAROCAINE DE RETRAITE (CMR)       4,13  ALLIANCES

# %%
shareholders.to_sql(name='api_shareholder',index=False,con=engine,if_exists='append')

# %%
# Create an empty DataFrame to store the result
Contact = pd.DataFrame()

# Iterate through rows of the original DataFrame
for index, row in df.iterrows():
    # Convert the value column to a dictionary (assuming it's a valid JSON-like format)
    values_dict = eval(row['investors_contact'])
    
    # Create a temporary DataFrame from the dictionary
    temp_df = pd.DataFrame.from_dict(values_dict, orient='index').T
    
    # Append the temporary DataFrame to the result DataFrame
    Contact = Contact.append(temp_df, ignore_index=True)

# Reset the index of the new DataFrame
Contact.reset_index(drop=True, inplace=True)

# Rename columns if needed
Contact.rename(columns=lambda x: x.strip(), inplace=True)

Contact['company_id']=df['side_full_name']
Contact.rename(columns={'Contacts': 'name','E-mail':'mail','Phone':'phone','Fax':'fax','Corporate Website':'website'}, inplace=True)

Contact.fillna('',inplace=True)

Contact.head()
# Out:
#                       name                            mail  \
# 0              Amine ALAMI          aalami@alliances.co.ma
# 1  Rachid IDRISSI KAITOUNI         r.idrissi@akwagroup.com
# 2         Radouane Ahliyat   radouane.ahliyat@afmagroup.ma
# 3           Ilyas El Harti            i.elharti@akdital.ma
# 4            Fares EL AKEL  f.elakel@aluminiumdumaroc.com.
#
#                                                phone  \
# 0                                   0522.99.34.84/63
# 1                                (212) 0522 35 21 44
# 2                                     05 22 42 80 00
# 3                                      0522 23 14 14
# 4  (212) 0539 32 99 50  Siège (Tanger) // (212) 0...
#
#                                                  fax  \
# 0                                      0522.99.34.81
# 1                                (212) 0522 35 22 39
# 2                                     05 22 42 80 60
# 3
# 4  212 0539 35 17 24  à Tanger/ 212 022 66 64 24 ...
#
# ...

# %%
Contact.to_sql(name='api_contact',index=False,con=engine,if_exists='append')

# %%
# key_figures :  {"Consolidated accounts": ["Yes", "Yes", "Yes"], "Share capital": ["2 207 858 800,00", "2 207 858 800,00", "2 207 858 800,00"], "Equity": ["3 401 448 000,00", "3 260 105 000,00", "3 348 605 000,00"], "Number of titles(2)": ["22 078 588", "22 078 588", "22 078 588"], "Sales figures": ["1 603 939 000,00", "1 413 801 000,00", "1 270 401 000,00"], "Operating result": ["320 931 000,00", "259 578 000,00", "-280 199 000,00"], "Net income (4)": ["178 385 000,00", "119 298 000,00", "-437 128 000,00"]}
# class KeyFigures(models.Model):
#     company = models.ForeignKey(Company, on_delete=models.PROTECT)
#     year = models.CharField(max_length=30, default="", unique=True)
#     consolidated_accounts = models.CharField(max_length=30, default="", unique=True)
#     share_capital = models.DecimalField(max_digits=10, decimal_places=2)
#     equity = models.DecimalField(max_digits=10, decimal_places=2)
#     number_of_titles = models.PositiveIntegerField(default=0)
#     sales_figures = models.DecimalField(max_digits=10, decimal_places=2)
#     operating_result = models.DecimalField(max_digits=10, decimal_places=2)
#     net_income = models.DecimalField(max_digits=10, decimal_places=2)
# Create an empty DataFrame to store the result

# %%
# {"BPA": ["8,08", "5,40", "-19,80"], "ROE (in %)": ["5,24", "3,66", "-13,05"], "Payout (in %)": ["-", "-", "-"], "Dividend yield (in %)": ["-", "-", "-"], "PER": ["6,44", "6,84", "-"], "PBR": ["0,34", "0,25", "0,24"]}
# class Ratios(models.Model):
#     company = models.ForeignKey(Company, on_delete=models.PROTECT)
#     year = models.CharField(max_length=30, default="", unique=True)
#     bpa = models.DecimalField(max_digits=5, decimal_places=2)
#     roe = models.DecimalField(max_digits=5, decimal_places=2)
#     payout = models.DecimalField(max_digits=5, decimal_places=2)
#     dividend_yield = models.DecimalField(max_digits=5, decimal_places=2)
#     per = models.DecimalField(max_digits=5, decimal_places=2)
#     pbr = models.DecimalField(max_digits=5, decimal_places=2)
Ratios=pd.DataFrame()

# %%
# dividende_details =  [['2013', '2012', '2011'], ['12,00', '20,00', '14,00'], ['Ordinary', 'Ordinary', 'Ordinary'], ['19/09/2014', '19/08/2013', '06/09/2012'], ['30/09/2014', '30/09/2013', '17/09/2012']]
# class Dividend(models.Model):
#     company = models.ForeignKey(Company, on_delete=models.PROTECT)
#     year = models.CharField(max_length=30, default="", unique=True)
#     amount = models.DecimalField(max_digits=10, decimal_places=2)
#     dividend_type = models.CharField(max_length=30, default="", unique=True)
#     ex_date = models.DateField(null=True, default=None)
#     payment_date = models.DateField(null=True, default=None)
Dividend=pd.DataFrame()
